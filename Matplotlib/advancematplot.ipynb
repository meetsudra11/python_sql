# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
print(type(plt))
# Out:
# <class 'module'>

# %%
iris = pd.read_csv('iris.csv')
iris.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# scatter plot shows correlation amoung variables 
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'])

# %%
iris['Species'] = iris['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
iris.sample(3)
# Out:
# /var/folders/8h/xtp_v7md6bs9195xxzbbf5d80000gn/T/ipykernel_1004/1296865378.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iris['Species'] = iris['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 140  141            6.7           3.1            5.6           2.4        2
# 65    66            6.7           3.1            4.4           1.4        1
# 45    46            4.8           3.0            1.4           0.3        0

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='winter',alpha=0.5)#winter,jet,summer,viridis, # alpha value gives the obesity to the chart 
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')

plt.colorbar() # values dega

# %%
plt.figure(figsize=(15,7))
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='winter',alpha=0.5)#winter,jet,summer,viridis, # alpha value gives the obesity to the chart 
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')

plt.colorbar() # values dega

# %%
bat = pd.read_csv('batter.csv')
bat.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
df_sample = bat.head(100).sample(25,random_state=5)
df_sample
# Out:
#            batter  runs        avg  strike_rate
# 66      KH Pandya  1326  22.100000   132.203390
# 32       SE Marsh  2489  39.507937   130.109775
# 46      JP Duminy  2029  39.784314   120.773810
# 28       SA Yadav  2644  29.707865   134.009123
# 74      IK Pathan  1150  21.698113   116.751269
# 23     JC Buttler  2832  39.333333   144.859335
# 10      G Gambhir  4217  31.007353   119.665153
# 20    BB McCullum  2882  27.711538   126.848592
# 17     KA Pollard  3437  28.404959   140.457703
# 35        WP Saha  2427  25.281250   124.397745
# 97  ST Jayasuriya   768  27.428571   134.031414
# 37     MA Agarwal  2335  22.669903   129.506378
# 70       DJ Hooda  1237  20.278689   127.525773
# 40         N Rana  2181  27.961538   130.053667
# 60      SS Tiwary  1494  28.730769   115.724245
# 34      JH Kallis  2427  28.552941   105.936272
# 42  KS Williamson  2105  36.293103   123.315759
# 57       DJ Bravo  1560  22.608696   125.100241
# 12      AM Rahane  4074  30.863636   117.575758
# ...

# %%
plt.scatter(df_sample['avg'],df_sample['strike_rate'],s=df_sample['runs'])

for i in range(df_sample.shape[0]):
    plt.text(df_sample['avg'].values[i],df_sample['strike_rate'].values[i],df_sample['batter'].values[i])

# %%
# players with strike rate greater then 130 and avg greater then 30
plt.scatter(df_sample['avg'],df_sample['strike_rate'])

plt.axhline(130,color='red')#axis horizontal line
plt.axhline(140,color='red')# exceptional hitters with high strike rate 
plt.axvline(30,color='green')


for i in range(df_sample.shape[0]):
    plt.text(df_sample['avg'].values[i],df_sample['strike_rate'].values[i],df_sample['batter'].values[i])

# %%
# A different way to plot graphs 
bat.head(3)
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577

# %%
plt.figure(figsize=(15,6))
plt.scatter(bat['avg'],bat['strike_rate'],color='green')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,6))
ax.scatter(bat['avg'],bat['strike_rate'],color='green')

ax.set_title('avg and strike rate of players')
ax.set_xlabel('avg')
ax.set_ylabel('strike_rate')

fig.show()
# Out:
# /var/folders/8h/xtp_v7md6bs9195xxzbbf5d80000gn/T/ipykernel_1004/870149667.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig,ax = plt.subplots(nrows=2,ncols=1,sharex=True)

ax[0].scatter(bat['avg'],bat['runs'])
ax[0].set_title('avg n runs')
ax[0].set_ylabel('runs')

ax[1].scatter(bat['avg'],bat['strike_rate'])
ax[1].set_title('avg n strike_rate')
ax[1].set_xlabel('average')
ax[1].set_ylabel('strike_rate')


plt.show()

# %%
# another way 
fig = plt.figure()

ax1 = fig.add_subplot(2,1,1)# 2rows 1column 1stchart 
ax1.scatter(bat['avg'],bat['strike_rate'])

ax2 = fig.add_subplot(2,1,2)# 2rows 1 column 2ndchart
ax2.scatter(bat['avg'],bat['runs'])

# %%
fig, ax = plt.subplots()
ax.plot([0,1,2],[0,1,4])

ax.text(1,1,'Point(1,1)')
ax.text(0,0,'Point(0,0)')
# .text is used to give the annotations
# Out:
# Text(0, 0, 'Point(0,0)')

# %%
bat.columns

fig = plt.figure(figsize=(10,4))
ax = plt.subplot(projection='3d')

ax.scatter3D(bat['runs'],bat['avg'],bat['strike_rate'])
ax.set_title('ipl batsman analysis')
ax.set_xlabel('runs')
ax.set_ylabel('avg')
ax.set_zlabel('strike_rate')
# Out:
# Text(0.5, 0, 'strike_rate')

# %%
# 3D line plot
x = [0,1,5]
y = [0,10,13]
z = [0,13,20]
fig = plt.figure()
ax = plt.subplot(projection='3d')
ax.scatter3D(x,y,z,s=[100,100,100])
ax.plot3D(x,y,z,color='green')

# %%
# 3D surface plot 
# x^2+y^2

x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

xx,yy = np.meshgrid(x,y)
z = xx**2 + yy**2

fig = plt.figure(figsize=(12,8))

ax = plt.subplot(projection='3d')
ax.plot_surface(xx,yy,z)
