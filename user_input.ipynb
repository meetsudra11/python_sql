# %% [markdown]
# When software talks to you, it is called static software. Clock, blogs, calendar
#
# Dynamic software - Youtube, facebook, whatsapp, a way of talking to the software. SO they are allowing you to take input.
#
# In todays world, mostly sare hi applications dynamic he.

# %%
input('enter your name')
# Out:
# 'meet'

# %%
a = int(input("enter any number"))
b = int(input("enter any number"))

result = a+b
print(result)
# Out:
# 5

# %%
type(result)
# Out:
# int

# %%
# type-conversions have two types 
# 1. implicit conversion
# 2. explicit conversion

# %%
4 + 5.5 #khudhi kardega samjk int + float
# Out:
# 9.5

# %%
5 + 6+7j
# Out:
# (11+7j)

# %%
4.5 + 5+5j
# Out:
# (9.5+5j)

# %%
# explicit functions 
print(int('4'))
print(float(4))
print(str(5))
print(bool(1))
print(list('hello'))
# Out:
# 4
# 4.0
# 5
# True
# ['h', 'e', 'l', 'l', 'o']

# %%
a = 4.5 
print(int(a)) # type conversion is not a permanent operation brother. 
print(a)
# Out:
# 4
# 4.5
