# %% [markdown]
# What are Modules?
# * Consider a module to be the same as a code library. It includes list of functions. U can import this file and try its functions.
# * They are just of code reusablilty

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# test_sqlite3: testing with SQLite version 3.45.1
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.8' (you have '2.0.5'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/pkgutil.py:78: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(info.name)
# ...

# %%
import math
math.sqrt(34)
# Out:
# 5.830951894845301

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.factorial(3)
# Out:
# 6

# %%
math.ceil(3.4)
# Out:
# 4

# %%
math.floor(3.4)
# Out:
# 3

# %%
import random 

a = random.randint(1,10)
a
# Out:
# 2

# %%
a = [1,2,4314,431,343,15,3,53,565,42,23]
random.shuffle(a)
a # permanent shuffling ho rahi he brother
# Out:
# [2, 565, 23, 53, 1, 42, 343, 15, 431, 4314, 3]

# %%
import time 

time.time()
# Out:
# 1768814169.545942

# %%
time.ctime()
# Out:
# 'Mon Jan 19 14:46:21 2026'

# %%
print("My name is")
time.sleep(0.5)
print("Meet Sudra")
# Out:
# My name is
# Meet Sudra

# %%
import os 

os.getcwd()
os.listdir()
# Out:
# ['problems4.ipynb',
#  'basics.ipynb',
#  'datatypes.ipynb',
#  'problems2.ipynb',
#  '.DS_Store',
#  'Python Notes.pdf',
#  'operators.ipynb',
#  'break-continue-pass.ipynb',
#  'problems5.ipynb',
#  'ifelse_loops.ipynb',
#  'problems1.ipynb',
#  'literals.ipynb',
#  'problems3.ipynb',
#  'functions.ipynb',
#  'practice.ipynb',
#  '.gitattributes',
#  'Matplotlib',
#  'typecasting.ipynb',
#  '.git',
#  '.vscode',
#  'built-in-functions.ipynb',
#  'built-in-modules.ipynb',
#  'user_input.ipynb',
#  'keywords-and-identifiers.ipynb',
#  'Pandas',
#  'SQL']
