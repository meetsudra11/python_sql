# %% [markdown]
# In python everything is object

# %%
a = 2
print(type(a))
# Out:
# <class 'int'>

# %% [markdown]
# What is class?
# * In python, a datatype is a class
# and a variable of that datatype is object.
#
# * us object k liye class k sare functions available honge.
#
# What does a class have?
# * data
# * functinalitites
#
# It shd be in PascalCase

# %%
class Car:
    color = "blue" # data
    model = "sports" # data

    def calculateAvgSpeed(km,time): # functionalities
        pass

# %% [markdown]
# Object is the instance of the class

# %%
wagnor = Car()

# %% [markdown]
# # Building a ATM software.
#
# * data :
# 1. acc no.
# 2. name.
# 3. bal.
# 4. atm print
#
# * methods : these are the functions written inside the class always rememmber
# 1. create_pin
# 2. deposit
# 3. withdraw
# 4. check_bal

# %%
class Atm:  

    # constructor - special method jisk andar rakha hua code automatically run hota he jese hi aap Atm class ka object banate ho 
    def __init__(self):
        self.pin = "3456"
        self.bal = 0 # variables created inside the constructuor is called instance variable for which the value is different for different objects.
        self.menu()
    
    def menu(self):
        user_input = input('''
                        Hello, how would you like to proceed?
                        1. Enter 1 to create pin
                        2. Enter 2 to deposit 
                        3. Enter 3 to withdraw
                        4. Enter 4 to check balance
                        5. Enter 5 to exit
''')
        if user_input == '1':
            self.create_pin()
        elif user_input =='2':
            self.deposit()
        elif user_input == '3':
            self.withdraw()
        elif user_input == '4':
            self.check_bal()
        else:
            print("bye")
        
    def create_pin(self):
        self.pin = input("enter you pin")
        print("Pin set successfully")

    def deposit(self):
        temp = input("enter your pin")
        if temp == self.pin:
            amount = int(input("Enter the amount"))
            self.bal = self.bal + amount
            print("Deposit successfully")
        else:
            print("Invalid pin")

    def withdraw(self):
        temp = input("enter your pin")
        if temp == self.pin:
            amount = int(input("Enter the amount"))
            if amount<self.bal:
                self.bal = self.bal-amount
                print("Operation successful")
            else:
                print("Insufficient funds")
        else:
            print("Invalid pin")

    def check_bal(self):
        temp = input("enter your pin")
        if temp == self.pin:
            print("Balance in your account:",self.bal)
        else:
            print("Invalid pin")

# %%
a = Atm()
# Out:
# Insufficient funds

# %% [markdown]
# # Lets create our own datatype.

# %%
class fraction:
     
     def __init__(self, num, den):
          self.num = num 
          self.den = den
          print(id(self))

     def __str__(self):
          return "{}/{}".format(self.num, self.den)
     
     def __add__(self,other): #x,y
          temp_num = self.num * other.den + other.num * self.den
          temp_den = self.den * other.den

          return "{}/{}".format(temp_num,temp_den)

     def __sub__(self,other): #x,y
          temp_num = self.num * other.den - other.num * self.den
          temp_den = self.den * other.den

          return "{}/{}".format(temp_num,temp_den)

# %%
f = fraction(2,3)
type(f)
# Out:
# 4367902736
# __main__.fraction

# %%
id(f)
# Out:
# 4367902736

# %%
print(type(f))
print(f)
# Out:
# <class '__main__.fraction'>
# 2/3

# %%
j = fraction(3,4)
print(j)
# Out:
# 4367907824
# 3/4

# %%
print(f+j)
# Out:
# 17/12

# %%
print(f-j)
# Out:
# -1/12

# %% [markdown]
# # Encapsulation

# %%
sbi = Atm()
# Out:
# Pin set successfully

# %% [markdown]
# The object can access botht he methods and the data. dono pin and bal access kar raha he

# %%
sbi.pin
sbi.bal
# Out:
# 0

# %%
sbi.bal = 'abc' # what if someone changed the value of variable. This is not a good practise to keep these data variables open.

# %%
sbi.deposit() # badme issue ate hee run it. It will throw you error
# Out:
# Invalid pin

# %% [markdown]
# Thus we need to make our variables private. This can be done using access modifiers.
# In python u have (__)

# %%
class Atm:  

    # constructor - special method jisk andar rakha hua code automatically run hota he jese hi aap Atm class ka object banate ho 
    def __init__(self):
        self.__pin = "3456"
        self.__bal = 0 # variables created inside the constructuor is called instance variable for which the value is different for different objects.
        self.menu()
    
    def menu(self):
        user_input = input('''
                        Hello, how would you like to proceed?
                        1. Enter 1 to create pin
                        2. Enter 2 to deposit 
                        3. Enter 3 to withdraw
                        4. Enter 4 to check balance
                        5. Enter 5 to exit
''')
        if user_input == '1':
            self.create_pin()
        elif user_input =='2':
            self.deposit()
        elif user_input == '3':
            self.withdraw()
        elif user_input == '4':
            self.check_bal()
        else:
            print("bye")
        
    def create_pin(self):
        self.__pin = input("enter you pin")
        print("Pin set successfully")

    def deposit(self):
        temp = input("enter your pin")
        if temp == self.__pin:
            amount = int(input("Enter the amount"))
            self.__bal = self.__bal + amount
            print("Deposit successfully")
        else:
            print("Invalid pin")

    def withdraw(self):
        temp = input("enter your pin")
        if temp == self.__pin:
            amount = int(input("Enter the amount"))
            if amount<self.__bal:
                self.__bal = self.__bal-amount
                print("Operation successful")
            else:
                print("Insufficient funds")
        else:
            print("Invalid pin")

    def check_bal(self):
        temp = input("enter your pin")
        if temp == self.__pin:
            print("Balance in your account:",self.__bal)
        else:
            print("Invalid pin")

# %%
sbi = Atm()
# Out:
# Pin set successfully

# %% [markdown]
# Now you wont be able to see data variables.

# %%
sbi.__bal = 'abc'

# %%
sbi.deposit()
# Out:
# Deposit successfully

# %%
sbi.check_bal()
# Out:
# Balance in your account: 5000

# %% [markdown]
# 1. how come this happened brother? code shd have been crashed.
#
# 2. But the reason is i created a new variable with the name "__bal" which is equal to "abc"
#
# 3. The private variable which we made is actually looking like this : "_Atm__bal" and not "__bal". SO yes python interpretor will look at every private variable in this sense : "_Atm__bal", "_Atm__pin" and so on

# %% [markdown]
# 1. Classes encapsulate data (attributes) and functionalities (methods).
# 2. A constructor (`__init__`) is essential for initializing object attributes.
# 3. Methods within a class require `self` to access instance variables and other methods.
# 4. An object is an instance of a class, allowing access to its data and methods.
# 5. Encapsulation protects data using access modifiers like `__` for private attributes.
# 6. In Python, private attributes are name-mangled (e.g., `__bal` becomes `_Atm__bal`) but not truly inaccessible.
# 7. To safely access or modify private data, implement getter and setter methods.

# %%
class Atm:  

    # constructor - special method jisk andar rakha hua code automatically run hota he jese hi aap Atm class ka object banate ho 
    def __init__(self):
        self.__pin = "3456"
        self.__bal = 0 # variables created inside the constructuor is called instance variable for which the value is different for different objects.
        self.menu()

    def get_pin(self):
        return self.__pin
    def set_pin(self,new_pin):
        if type(new_pin) == str:
            self.__pin = new_pin
            print("Pin changed successfully")
        else:
            print("not alloweds")
        
    
    def menu(self):
        user_input = input('''
                        Hello, how would you like to proceed?
                        1. Enter 1 to create pin
                        2. Enter 2 to deposit 
                        3. Enter 3 to withdraw
                        4. Enter 4 to check balance
                        5. Enter 5 to exit
''')
        if user_input == '1':
            self.create_pin()
        elif user_input =='2':
            self.deposit()
        elif user_input == '3':
            self.withdraw()
        elif user_input == '4':
            self.check_bal()
        else:
            print("bye")
        
    def create_pin(self):
        self.__pin = input("enter you pin")
        print("Pin set successfully")

    def deposit(self):
        temp = input("enter your pin")
        if temp == self.__pin:
            amount = int(input("Enter the amount"))
            self.__bal = self.__bal + amount
            print("Deposit successfully")
        else:
            print("Invalid pin")

    def withdraw(self):
        temp = input("enter your pin")
        if temp == self.__pin:
            amount = int(input("Enter the amount"))
            if amount<self.__bal:
                self.__bal = self.__bal-amount
                print("Operation successful")
            else:
                print("Insufficient funds")
        else:
            print("Invalid pin")

    def check_bal(self):
        temp = input("enter your pin")
        if temp == self.__pin:
            print("Balance in your account:",self.__bal)
        else:
            print("Invalid pin")

# %%
sbi = Atm()
# Out:
# Pin set successfully

# %%
sbi.get_pin()
# Out:
# '1234'

# %%
sbi.set_pin(5) # kyuki mene script vese likhi he
# Out:
# not alloweds

# %%
sbi._Atm__pin = 'meet'

# %%
sbi.get_pin()
# Out:
# 'meet'

# %% [markdown]
# # Reference variables

# %%
Atm()
# Out:
# Pin set successfully

# %% [markdown]
# * the above object is stored at given address. But there is no variable pointing this location.
# * Thus we need a variable

# %%
sbi = Atm() # this is called ref variables
# Out:
# Pin set successfully

# %% [markdown]
# # Pass by reference

# %%
class Customer:
    def __init__(self,name,gender):
        self.name = name
        self.gender = gender

cust = Customer("Meet","Male")
cust2 = Customer("Arti","Female")

# %%
print(cust2.name)
print(cust2.gender)
# Out:
# Arti
# Female

# %% [markdown]
# * A function can be given a object of class

# %%
def greet(customer):
    if customer.gender == "Male":
        print("Hello",customer.name,"Sir")
    else:
        print("Hello",customer.name,"Ma'am")

greet(cust2)
# Out:
# Hello Arti Ma'am

# %%
class Customer:
    def __init__(self,name):
        self.name = name


cust = Customer("Ankita")
print(id(cust))
print(cust.name)
# Out:
# 4367683552
# Ankita

# %%
def greet(customer):
    print(id(customer))
    customer.name = "Nitish"
    print(customer.name) # objects of class are also mutable like list, dict and sets 
    print(id(customer))

greet(cust)
# Out:
# 4367683552
# Nitish
# 4367683552

# %% [markdown]
# * Agar koi function kisi object ko leta he and voh function uss object k kisi attribute ko change kar deta hee, that remains forever. The object attribute changes permanently.
#
# * when functino changes the attribute of an object of a class, changes are made at that location only. Means mutability hee

# %%
def change(L):
    print(id(L))
    L.append(5)
    print(L)
    print(id(L))

# %%
l1 = list([1,2,3,4])
print(l1)
# Out:
# [1, 2, 3, 4]

# %%
change(l1)
# Out:
# 4444392768
# [1, 2, 3, 4, 5]
# 4444392768

# %% [markdown]
# # Collection of objects

# %%
class Customer: 
    def __init__(self,name,age):
        self.name = name 
        self.age = age

# %%
c1 = Customer("Meet",23)
c2 = Customer("Heeta",45)
c3 = Customer("Neha",32)

L = [c1,c2,c3]

# %%
for i in L:
    print(i.name, i.age)
# Out:
# Meet 23
# Heeta 45
# Neha 32

# %% [markdown]
# # Static methods

# %%
class Atm:  

    __counter = 1 # this is statis variable or class variable 

    # constructor - special method jisk andar rakha hua code automatically run hota he jese hi aap Atm class ka object banate ho 
    def __init__(self):
        self.__pin = "3456"
        self.__bal = 0 # variables created inside the constructuor is called instance variable for which the value is different for different objects.
        self.sno = Atm.__counter
        Atm.__counter = Atm.__counter + 1
        # self.menu()

    @staticmethod
    def get_counter():
        return Atm.__counter
    @staticmethod 
    def set_counter(new):
        if type(new) == int:
            Atm.__counter = new
        else:
            print("not allowed")

    # these above 2 functions deal with static variables and hence they dont need self. And hence they are called as static methods.

    def get_pin(self):
        return self.__pin
    def set_pin(self,new_pin):
        if type(new_pin) == str:
            self.__pin = new_pin
            print("Pin changed successfully")
        else:
            print("not alloweds")
        
    
    def menu(self):
        user_input = input('''
                        Hello, how would you like to proceed?
                        1. Enter 1 to create pin
                        2. Enter 2 to deposit 
                        3. Enter 3 to withdraw
                        4. Enter 4 to check balance
                        5. Enter 5 to exit
''')
        if user_input == '1':
            self.create_pin()
        elif user_input =='2':
            self.deposit()
        elif user_input == '3':
            self.withdraw()
        elif user_input == '4':
            self.check_bal()
        else:
            print("bye")
        
    def create_pin(self):
        self.__pin = input("enter you pin")
        print("Pin set successfully")

    def deposit(self):
        temp = input("enter your pin")
        if temp == self.__pin:
            amount = int(input("Enter the amount"))
            self.__bal = self.__bal + amount
            print("Deposit successfully")
        else:
            print("Invalid pin")

    def withdraw(self):
        temp = input("enter your pin")
        if temp == self.__pin:
            amount = int(input("Enter the amount"))
            if amount<self.__bal:
                self.__bal = self.__bal-amount
                print("Operation successful")
            else:
                print("Insufficient funds")
        else:
            print("Invalid pin")

    def check_bal(self):
        temp = input("enter your pin")
        if temp == self.__pin:
            print("Balance in your account:",self.__bal)
        else:
            print("Invalid pin")

# %% [markdown]
# * static variables are those variables whose value remains same for every object.

# %%
cust1 = Atm()

# %%
cust1.sno
# Out:
# 1

# %%
Atm.get_counter()
# Out:
# 2

# %%
Atm.set_counter(5)

# %%
Atm.get_counter()
# Out:
# 5

# %% [markdown]
# # Relationships
#
# There are two types of it.
# * Aggregation : (Has-a)
# * Inheritance : (Is-a)

# %% [markdown]
# # Aggregation
#
# We have two classes : Customer class - Address class
#
# So here relation is as such:
# Customer has-a Address

# %%
class Customer:
    def __init__(self,name,gender,address):
        self.name = name
        self.gender = gender
        self.address = address

    def edit_profile(self, new_name, new_city, new_pincode, new_state):
        self.name = new_name 
        self.address.change_address(new_city,new_pincode, new_state)
        
class Address: 
    def __init__(self,city,pincode,state):
        self.city = city
        self.pincode = pincode
        self.state = state

    def change_address(self, new_city, new_pinecode, new_state):
        self.city = new_city
        self.pincode = new_pinecode
        self.state = new_state

# %%
add = Address("Kolkata",400068, "west-bengal")
cust = Customer("Meet","Male",add)

print(cust.address.city)
print(cust.address.pincode)
print(cust.address.state)
# Out:
# Kolkata
# 400068
# west-bengal

# %%
add.change_address("Mumbai",400068,"Maharashtra")

# %%
print(cust.address.city)
print(cust.address.pincode)
print(cust.address.state)
# Out:
# Mumbai
# 400068
# Maharashtra

# %%
cust.edit_profile("Meet","Mumbai", 122011,"haryana")

# %%
cust.address.city
cust.address.pincode
cust.address.state
# Out:
# 'haryana'

# %% [markdown]
# # Inheritance

# %% [markdown]
# Okay so inhertance basically gives code reusability.
#
# Baap k genes i will carry.
#
# Similary,
# 1. data members
# 2. member functions - methods
# 3. constructors as well
#
# can be inherited by child class from the parent class.
#
# You cant inherit private members.

# %%
class User: 
    def login(self):
        print("login")
    def register(self):
        print("register")

class Student(User): # User is a parent class 
    def enroll(self):
        print("enroll")
    def review(self):
        print("review")

# %%
stu1 = Student()

# %%
print(stu1.enroll())
print(stu1.login())
print(stu1.register())
print(stu1.review())
# Out:
# enroll
# None
# login
# None
# register
# None
# review
# None

# %%
class Phone:
    def __init__(self, price, brand, camera):
        print("Inside phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera

class SmartPhone(Phone):
    pass

# %% [markdown]
# see here we are inheriting constructor as well

# %%
s = SmartPhone(20000, "Apple", 13)
# Out:
# Inside phone constructor

# %%
s.brand
# Out:
# 'Apple'

# %% [markdown]
# * inheriting private members

# %%
class Phone:
    def __init__(self, price, brand, camera):
        print("Inside phone constructor")
        self.price = price
        self.__brand = brand # private data member
        self.camera = camera

class SmartPhone(Phone):
    pass

# %%
s = SmartPhone(20000, "Apple", 13)
# print(s.__brand) # object has no access
# Out:
# Inside phone constructor

# %% [markdown]
# * Polymorphism

# %%
class Phone:
    def __init__(self, price, brand, camera):
        print("Inside phone constructor")
        self.price = price
        self.__brand = brand # private data member
        self.camera = camera

    def buy(self):
        print("Buying a Phone")

class SmartPhone(Phone):
    
    def buy(self):
        print("Buying a Smartphone")

# %% [markdown]
# Both parent and child class have same methods. toh konsa run hoga in below cell.
#
# jis class ka object he ussi class ka run hoga and this is called method overriding This is polymorphism

# %%
s = SmartPhone(20000, "Apple", 13)
s.buy()
# Out:
# Inside phone constructor
# Buying a Smartphone

# %%
class Parent:    
    def __init__(self, num):
        self.__num = num

    def get_num(self):
        return self.__num

class Child(Parent):
    def show(self):
        print("This is in child class")

son = Child(100)
print(son.get_num())
son.show()
# Out:
# 100
# This is in child class

# %%
class Parent:
    def __init__(self, num):
        self.__num = num 

    def get_num(self):
        return self.__num
    
class Child(Parent):
    def __init__(self, val,num):
        self.__val=val
