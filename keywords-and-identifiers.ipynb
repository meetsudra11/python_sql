# %% [markdown]
# * python is case-sensitive language.
# * in python is a reserved word by program because the word has the special meaning. It can be commands or parameters

# %%
# python has 33 keywords 
import keyword 
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # idenitfiers
# It is a name used to idenitify a variable, function, class, module or ot  her object. We create identifiers

# %%
name = "meet"
print(name)
# Out:
# meet

# %%
_ = "meet"
print(_)
# Out:
# meet

# %%
* = "meet"
print(*)
# Out:
#   Cell In[7], line 1
#     * = "meet"
#       ^
# SyntaxError: invalid syntax

# %%
1name = "meet"
print(1name)
# Out:
#   Cell In[8], line 1
#     1name = "meet"
#     ^
# SyntaxError: invalid decimal literal

# %%
name1032434____ = "meet"
# everything except special characters after character
